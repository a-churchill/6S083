# %% [markdown]
# # 6.S083 Problem Set 1: Data Analysis
#
# ## Andrew Churchill

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# ### 1.

# %%
url = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv";

# %%
download(url, "covid_data_ps1.csv");

# %%
using CSV;
data = CSV.read("covid_data_ps1.csv");

# %%
using DataFrames;
rename!(data, 1 => "province", 2 => "country");

# %%
all_countries = collect(data[:, 2]);

# %% [markdown]
# ### 2

# %%
countries = [
    "China", 
    "Japan", 
    "Korea, South", 
    "US", 
    "United Kingdom", 
    "France", 
    "Germany"
];

# %% [markdown]
# ### 3.

# %%
num_days = length(convert(Vector, data[1, 5:end]))
# Out:
# 76

# %% [markdown]
# ### 4.

# %%
country_counts = Dict(
    country => zeros(Int64, num_days) for country in countries
);
for country in countries
    country_rows = [name == country for name in all_countries]
    country_data = data[country_rows, 5:end]
    for row in 1:size(country_data, 1)
        row_counts = convert(Vector, country_data[row, :])
        country_counts[country] += row_counts
    end
end

# %% [markdown]
# ### 5.

# %%
using Plots
using Dates

# %%
date_strs = String.(names(data[:, 5:end]))
format = Dates.DateFormat("m/d/Y")
dates = parse.(Date, date_strs, format) .+ Year(2000);

# %%
p = plot(
    leg=:topleft, 
    xticks=dates[1:5:end], 
    xrotation=45, 
    xlabel="Date", 
    ylabel="Confirmed Cases", 
    title="Covid-19 Cases Worldwide"
)
for (country, counts) in country_counts
    plot!(p, dates, counts, label=country, m=:o)
end
p

# %% [markdown]
# ### 6.

# %%
# Note: this method (setting to 1 if it's 0, to fix for the log scale, instead of
# NaN) works much more cleanly with the later parts of the lab, with the scatterplots,
# so I wrote it this way to keep the implementation cleaner.
function process_counts(counts)
    return [x == 0 ? Float64(1) : Float64(x) for x in counts]
end

p_log = plot(
    leg=:topleft, 
    xticks=dates[1:5:end], 
    xrotation=45, 
    xlabel="Date", 
    ylabel="Confirmed Cases", 
    title="Covid-19 Cases Worldwide",
    yscale=:log
)
for (country, counts) in country_counts
    plot!(p_log, dates, process_counts(counts), label=country, m=:o)
end
p_log

# %% [markdown]
# We definitely are seeing exponential growth, although in many of the countries it appears to be leveling off.

# %% [markdown]
# ### 7.

# %%
using Interact
# Out:
# HTML{String}("<script>\n// Immediately-invoked-function-expression to avoid global variables.\n(function() {\n    var warning_div = document.getElementById(\"webio-warning-14876877792679275443\");\n    var hide = function () {\n        var script = document.getElementById(\"webio-setup-7922817956085715128\");\n        var parent = script && script.parentElement;\n        var grandparent = parent && parent.parentElement;\n        if (grandparent) {\n            grandparent.style.display = \"none\";\n        }\n        warning_div.style.display = \"none\";\n    };\n    if (typeof Jupyter !== \"undefined\") {\n        console.log(\"WebIO detected Jupyter notebook environment.\");\n        // Jupyter notebook.\n        var extensions = (\n            Jupyter\n            && Jupyter.notebook.config.data\n            && Jupyter.notebook.config.data.load_extensions\n        );\n        if (extensions && extensions[\"webio-jupyter-notebook\"]) {\n            // Extension already loaded.\n   
# ...

# %%
function plot_to_day(day)
    p_i = plot(
        leg=:topleft, 
        xticks=dates[1:5:end], 
        xrotation=45, 
        xlim=map(Dates.value, (dates[1], dates[end])),
        xlabel="Date", 
        ylabel="Confirmed Cases", 
        title="Covid-19 Cases Worldwide"
    )
    for (country, counts) in country_counts
        plot!(p_i, dates[1:day], counts[1:day], label=country, m=:o)
    end
    return p_i
end

@manipulate for day in 1:num_days
    plot_to_day(day)
end
# Out:
# Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Scope(Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :label), Any["day"], Dict{Symbol,Any}(:className => "interact ",:style => Dict{Any,Any}(:padding => "5px 10px 0px 10px")))], Dict{Symbol,Any}(:className => "interact-flex-row-left")), Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :input), Any[], Dict{Symbol,Any}(:max => 76,:min => 1,:attributes => Dict{Any,Any}(:type => "range",Symbol("data-bind") => "numericValue: index, valueUpdate: 'input', event: {change: function (){this.changes(this.changes()+1)}}","orient" => "horizontal"),:step => 1,:className => "slider slider is-fullwidth",:style => Dict{Any,Any}()))], Dict{Symbol,Any}(:className => "interact-flex-row-center")), Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes => D
# ...

# %% [markdown]
# ## Exercise 2

# %% [markdown]
# ### 1.

# %%
total_cases_to_date = country_counts;

# %%
total_cases_to_date["All Countries"] = zeros(num_days)
for day in 1:num_days
#     @show collect(data[:, day + 3])
    day_total = sum(collect(data[:, day + 4]))
    total_cases_to_date["All Countries"][day] = day_total
end
push!(countries, "All Countries");

# %% [markdown]
# ### 2.

# %%
new_cases = Dict(country => zeros(Int64, num_days) for country in countries)
for (country, counts) in total_cases_to_date
    for day in 1:num_days
        last_week = counts[max(day - 7, 1)]
        today = counts[day]
        new_cases[country][day] = today - last_week
    end
end

# %% [markdown]
# ### 3.

# %%
function plot_new_vs_total(day)
    p_nvt = plot(
        leg=:topleft, 
        xlabel="Total Cases", 
        ylabel="New Cases", 
        title="Covid-19 Cases Worldwide",
        xscale=:log,
        yscale=:log
    )
    for country in countries
        x_vals = process_counts(total_cases_to_date[country][1:day])
        y_vals = process_counts(new_cases[country][1:day])
        plot!(
            p_nvt, 
            x_vals, 
            y_vals,
            label=country,
#             m=:o
        )
    end
    return p_nvt
end

@manipulate for day in 1:num_days
    plot_new_vs_total(day)
end
# Out:
# Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Scope(Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :label), Any["day"], Dict{Symbol,Any}(:className => "interact ",:style => Dict{Any,Any}(:padding => "5px 10px 0px 10px")))], Dict{Symbol,Any}(:className => "interact-flex-row-left")), Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :input), Any[], Dict{Symbol,Any}(:max => 76,:min => 1,:attributes => Dict{Any,Any}(:type => "range",Symbol("data-bind") => "numericValue: index, valueUpdate: 'input', event: {change: function (){this.changes(this.changes()+1)}}","orient" => "horizontal"),:step => 1,:className => "slider slider is-fullwidth",:style => Dict{Any,Any}()))], Dict{Symbol,Any}(:className => "interact-flex-row-center")), Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes => D
# ...

# %% [markdown]
# ### 4.

# %%
function plot_new_vs_total_scatter(day, scale)
    p_nvt = plot(
        leg=:topleft, 
        xlabel="Total Cases", 
        ylabel="New Cases", 
        title="Covid-19 Cases Worldwide",
        xscale=scale,
        yscale=scale
    )
    for country in countries
        x_vals = process_counts(total_cases_to_date[country][1:day])
        y_vals = process_counts(new_cases[country][1:day])
        plot!(
            p_nvt, 
            x_vals, 
            y_vals,
            label=country,
#             m=:o
        )
        scatter!(p_nvt, x_vals[end:end], y_vals[end:end], label="", color=:black)
        annotate!(p_nvt, x_vals[end], y_vals[end], text(country, 10, :black))
    end
    return p_nvt
end

@manipulate for day in 1:num_days, scale=[:identity, :log10]
    plot_new_vs_total_scatter(day, scale)
end
# Out:
# Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Scope(Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :label), Any["day"], Dict{Symbol,Any}(:className => "interact ",:style => Dict{Any,Any}(:padding => "5px 10px 0px 10px")))], Dict{Symbol,Any}(:className => "interact-flex-row-left")), Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :input), Any[], Dict{Symbol,Any}(:max => 76,:min => 1,:attributes => Dict{Any,Any}(:type => "range",Symbol("data-bind") => "numericValue: index, valueUpdate: 'input', event: {change: function (){this.changes(this.changes()+1)}}","orient" => "horizontal"),:step => 1,:className => "slider slider is-fullwidth",:style => Dict{Any,Any}()))], Dict{Symbol,Any}(:className => "interact-flex-row-center")), Node{WebIO.DOM}(WebIO.DOM(:html, :div), Any[Node{WebIO.DOM}(WebIO.DOM(:html, :p), Any[], Dict{Symbol,Any}(:attributes => D
# ...

# %% [markdown]
# For transcript correction, I did lecture 2, lines 460-479.
